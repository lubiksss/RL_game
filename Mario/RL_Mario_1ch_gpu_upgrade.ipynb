# %%
from collections import deque as dq
import random

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
# Modules needed to transform Mario_env to fit ML Model
from env_transform import *
# Gym is an OpenAI toolkit for RL
import gym
from gym.spaces import Box
from gym.wrappers import FrameStack
# NES Emulator for OpenAI Gym
from nes_py.wrappers import JoypadSpace
# Super Mario environment for OpenAI Gym
import gym_super_mario_bros

# %%
# Initialize Super Mario environment
env = gym_super_mario_bros.make("SuperMarioBros-1-1-v0")
# Limit the action-space to
#   0. walk right
#   1. jump right
env = JoypadSpace(env, [["right"], ["right", "A"]])


# Apply Wrappers to environment
env = SkipFrame(env, skip=4)
env = GrayScaleObservation(env)
env = ResizeObservation(env, shape=84)
# env = FrameStack(env, num_stack=4)

# env.reset()
# next_state, reward, done, info = env.step(action=1)
# print(f"{next_state.shape},\n {reward},\n {done},\n {info}")

# %%
# NN를 학습시키기 위한 hyperparameter
learning_rate = 0.0005
batch_size = 32
gamma = 0.98
buffer_limit = 100000

gpu = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 강화학습은 Training data set이라는게 따로 없다. Agent가 행동을 취하고 데이터셋을 쌓아나가야합니다.
# 그 데이터셋을 쌓기 위한 버퍼
class ReplayBuffer():
    def __init__(self):
        self.buffer = dq(maxlen=buffer_limit)
    
    # 버퍼에는 (state, action ,reward, nstate, done) 값이 들어갑니다.
    def put(self, transition):
        self.buffer.append(transition)
    
    # 샘플 함수를 만드는 이유는 버퍼에 쌓인 데이터셋에서 랜덤으로 학습을 시키기 위함입니다.
    # 그냥 연속해서 쌓인 n개의 데이터셋을 그대로 사용하면 데이터간의 상관관계가 너무 크기 때문에 학슴이 잘 안됩니다.
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
           
        return torch.tensor(s_lst, dtype=torch.float, device=gpu), torch.tensor(a_lst, device=gpu), \
               torch.tensor(r_lst, dtype=torch.float, device=gpu), torch.tensor(s_prime_lst, dtype=torch.float, device=gpu), \
               torch.tensor(done_mask_lst, dtype=torch.float, device=gpu)
    
    def size(self):
        return len(self.buffer)

# %%
# Mario의 state가 (4, 84, 84)sahpe, action은 2개이기 때문에 input 3, output 2인 CNN생성
class Qnet(nn.Module):
    def __init__(self):
        super(Qnet, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1,out_channels = 32,kernel_size = 8,stride = 4)
        self.conv2 = nn.Conv2d(in_channels = 32,out_channels = 64,kernel_size = 4,stride = 2)
        self.conv3 = nn.Conv2d(in_channels = 64,out_channels = 64,kernel_size = 3,stride = 1)
        self.fc1 = nn.Linear(5184, 512)
        self.fc2 = nn.Linear(512, 2)

    def forward(self, x):
        x = x.to(gpu)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(-1,5184)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x.float()
    
    # epsilon greedy 전략을 사용합니다.
    # 간단하게 설명하면 탐험이라는 개념을 통해서 가보지 않은 경로를 가볼 수 있게 해줍니다.
    def sample_action(self, observation, epsilon):
        out = self.forward(observation)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,1)
        else : 
            return out.argmax().item()

# %%
def train(q, q_target, memory, optimizer):
    for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)
        
        # 벨만함수로부터 유도된 DQN 비용함수를 구현 학습시킵니다.
        q_out = q(s)
        q_a = q_out.gather(1,a)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(q_a, target)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
# Double Deep Q Learning 개념
# target_net을 semi constant로 사용
q = Qnet().to(gpu)
q_target = Qnet().to(gpu)
q_target.load_state_dict(q.state_dict())
memory = ReplayBuffer()

print_interval = 20
score = 0.0  
optimizer = optim.Adam(q.parameters(), lr=learning_rate)

for n_epi in range(40000+1):
    print(f'epi : {n_epi}')
    epsilon = max(0.01, 0.08 - 0.01*(n_epi/200)) #Linear annealing from 8% to 1%
    s = env.reset()
    done = False

    while not done:
        a = q.sample_action((s.unsqueeze(0).unsqueeze(0)).float(), epsilon)
        s_prime, r, done, info = env.step(a)
        done_mask = 0.0 if done else 1.0
#         print(s.unsqueeze(0).shape, type(s.unsqueeze(0)))
#         print(a, type(a))
#         print(r, type(r))
#         print(s_prime.unsqueeze(0).shape, type(s_prime.unsqueeze(0)))
#         print(done_mask, type(done_mask))
        memory.put((s.unsqueeze(0).numpy(),a,r/100.0,s_prime.unsqueeze(0).numpy(), done_mask))
        s = s_prime

        score += r
        if done:
            break
    
    # 메모리가 어느정도 차야 random sample이 가능하기 때문에 일정 이상 차면 학습을 진행
    if memory.size()>2000:
        train(q, q_target, memory, optimizer)

    if n_epi%print_interval==0 and n_epi!=0:
        torch.save(q.state_dict(), 'Mario_weight.pt')
        f = open('./reward.txt', 'a')
        f.write("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%\n".format(
                                                        n_epi, score/print_interval, memory.size(), epsilon*100))
        f.close()
        # 일정 주기마다 semi constant인 target-net도 업데이트.
        q_target.load_state_dict(q.state_dict())
        print("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%".format(
                                                        n_epi, score/print_interval, memory.size(), epsilon*100))
        score = 0.0
env.close()
# Out:
# epi : 0
# epi : 1
# epi : 2
# epi : 3
# epi : 4
# epi : 5
# epi : 6
# epi : 7
# epi : 8
# epi : 9
# epi : 10
# epi : 11
# epi : 12
# epi : 13
# epi : 14
# epi : 15
# epi : 16
# epi : 17
# epi : 18
# epi : 19
# epi : 20
# n_episode :20, score : 353.9, n_buffer : 3729, eps : 7.9%
# epi : 21
# epi : 22
# epi : 23
# epi : 24
# epi : 25
# epi : 26
# epi : 27
# epi : 28
# epi : 29
# epi : 30
# epi : 31
# epi : 32
# epi : 33
# epi : 34
# epi : 35
# epi : 36
# epi : 37
# epi : 38
# epi : 39
# epi : 40
# n_episode :40, score : 439.0, n_buffer : 9716, eps : 7.8%
# epi : 41
# epi : 42
# epi : 43
# epi : 44
# epi : 45
# epi : 46
# epi : 47
# epi : 48
# epi : 49
# epi : 50
# epi : 51
# epi : 52
# epi : 53
# epi : 54
# epi : 55
# epi : 56
# epi : 57
# epi : 58
# epi : 59
# epi : 60
# n_episode :60, score : 445.1, n_buffer : 11450, eps : 7.7%
# epi : 61
# epi : 62
# epi : 63
# epi : 64
# epi : 65
# epi : 66
# epi : 67
# epi : 68
# epi : 69
# epi : 70
# epi : 71
# epi : 72
# epi : 73
# epi : 74
# epi : 75
# epi : 76
# epi : 77
# epi : 78
# epi : 79
# epi : 80
# n_episode :80, score : 469.2, n_buffer : 19220, eps : 7.6%
# epi : 81
# epi : 82
# epi : 83
# epi : 84
# epi : 85
# epi : 86
# epi : 87
# epi : 88
# epi : 89
# epi : 90
# epi : 91
# epi : 92
# epi : 93
# epi : 94
# epi : 95
# epi : 96
# epi : 97
# epi : 98
# epi : 99
# epi : 100
# n_episode :100, score : 562.9, n_buffer : 21481, eps : 7.5%
# epi : 101
# epi : 102
# epi : 103
# epi : 104
# epi : 105
# epi : 106
# epi : 107
# epi : 108
# epi : 109
# epi : 110
# epi : 111
# epi : 112
# epi : 113
# epi : 114
# epi : 115
# epi : 116
# epi : 117
# epi : 118
# epi : 119
# epi : 120
# n_episode :120, score : 494.9, n_buffer : 23568, eps : 7.4%
# epi : 121
# epi : 122
# epi : 123
# epi : 124
# epi : 125
# epi : 126
# epi : 127
# epi : 128
# epi : 129
# epi : 130
# epi : 131
# epi : 132
# epi : 133
# epi : 134
# epi : 135
# epi : 136
# epi : 137
# epi : 138
# epi : 139
# epi : 140
# n_episode :140, score : 515.9, n_buffer : 31616, eps : 7.3%
# epi : 141
# epi : 142
# epi : 143
# epi : 144
# epi : 145
# epi : 146
# epi : 147
# epi : 148
# epi : 149
# epi : 150
# epi : 151
# epi : 152
# epi : 153
# epi : 154
# epi : 155
# epi : 156
# epi : 157
# epi : 158
# epi : 159
# epi : 160
# n_episode :160, score : 470.6, n_buffer : 35614, eps : 7.2%
# epi : 161
# epi : 162
# epi : 163
# epi : 164
# epi : 165
# epi : 166
# epi : 167
# epi : 168
# epi : 169
# epi : 170
# epi : 171
# epi : 172
# epi : 173
# epi : 174
# epi : 175
# epi : 176
# epi : 177
# epi : 178
# epi : 179
# epi : 180
# n_episode :180, score : 648.9, n_buffer : 46317, eps : 7.1%
# epi : 181
# epi : 182
# epi : 183
# epi : 184
# epi : 185
# epi : 186
# epi : 187
# epi : 188
# epi : 189
# epi : 190
# epi : 191
# epi : 192
# epi : 193
# epi : 194
# epi : 195
# epi : 196
# epi : 197
# epi : 198
# epi : 199
# epi : 200
# n_episode :200, score : 564.3, n_buffer : 52486, eps : 7.0%
# epi : 201
# epi : 202
# epi : 203
# epi : 204
# epi : 205
# epi : 206
# epi : 207
# epi : 208
# epi : 209
# epi : 210
# epi : 211
# epi : 212
# epi : 213
# epi : 214
# epi : 215
# epi : 216
# epi : 217
# epi : 218
# epi : 219
# epi : 220
# n_episode :220, score : 511.1, n_buffer : 56488, eps : 6.9%
# epi : 221
# epi : 222
# epi : 223
# epi : 224
# epi : 225
# epi : 226
# epi : 227
# epi : 228
# epi : 229
# epi : 230
# epi : 231
# epi : 232
# epi : 233
# epi : 234
# epi : 235
# epi : 236
# epi : 237
# epi : 238
# epi : 239
# epi : 240
# n_episode :240, score : 664.9, n_buffer : 63153, eps : 6.8%
# epi : 241
# epi : 242
# epi : 243
# epi : 244
# epi : 245
# epi : 246
# epi : 247
# epi : 248
# epi : 249
# epi : 250
# epi : 251
# epi : 252
# epi : 253
# epi : 254
# epi : 255
# epi : 256
# epi : 257
# epi : 258
# epi : 259
# epi : 260
# n_episode :260, score : 516.8, n_buffer : 73352, eps : 6.7%
# epi : 261
# epi : 262
# epi : 263
# epi : 264
# epi : 265
# epi : 266
# epi : 267
# epi : 268
# epi : 269
# epi : 270
# epi : 271
# epi : 272
# epi : 273
# epi : 274
# epi : 275
# epi : 276
# epi : 277
# epi : 278
# epi : 279
# epi : 280
# n_episode :280, score : 489.4, n_buffer : 81529, eps : 6.6%
# epi : 281
# epi : 282
# epi : 283
# epi : 284
# epi : 285
# epi : 286
# epi : 287
# epi : 288
# epi : 289
# epi : 290
# epi : 291
# epi : 292
# epi : 293
# epi : 294
# epi : 295
# epi : 296
# epi : 297
# epi : 298
# epi : 299
# epi : 300
# n_episode :300, score : 565.7, n_buffer : 87553, eps : 6.5%
# epi : 301
# epi : 302
# epi : 303
# epi : 304
# epi : 305
# epi : 306
# epi : 307
# epi : 308
# epi : 309
# epi : 310
# epi : 311
# epi : 312
# epi : 313
# epi : 314
# epi : 315
# epi : 316
# epi : 317
# epi : 318
# epi : 319
# epi : 320
# n_episode :320, score : 575.4, n_buffer : 95890, eps : 6.4%
# epi : 321
# epi : 322
# epi : 323
# epi : 324
# epi : 325
# epi : 326
# epi : 327
# epi : 328
# epi : 329
# epi : 330
# epi : 331
# epi : 332
# epi : 333
# epi : 334
# epi : 335
# epi : 336
# epi : 337
# epi : 338
# epi : 339
# epi : 340
# n_episode :340, score : 661.3, n_buffer : 98558, eps : 6.3%
# epi : 341
# epi : 342
# epi : 343
# epi : 344
# epi : 345
# epi : 346
# epi : 347
# epi : 348
# epi : 349
# epi : 350
# epi : 351
# epi : 352
# epi : 353
# epi : 354
# epi : 355
# epi : 356
# epi : 357
# epi : 358
# epi : 359
# epi : 360
# n_episode :360, score : 546.5, n_buffer : 100000, eps : 6.2%
# epi : 361
# epi : 362
# epi : 363
# epi : 364
# epi : 365
# epi : 366
# epi : 367
# epi : 368
# epi : 369
# epi : 370
# epi : 371
# epi : 372
# epi : 373
# epi : 374
# epi : 375
# epi : 376
# epi : 377
# epi : 378
# epi : 379
# epi : 380
# n_episode :380, score : 819.0, n_buffer : 100000, eps : 6.1%
# epi : 381
# epi : 382
# epi : 383
# epi : 384
# epi : 385
# epi : 386
# epi : 387
# epi : 388
# epi : 389
# epi : 390
# epi : 391
# epi : 392
# epi : 393
# epi : 394
# epi : 395
# epi : 396
# epi : 397
# epi : 398
# epi : 399
# epi : 400
# n_episode :400, score : 596.1, n_buffer : 100000, eps : 6.0%
# epi : 401
# epi : 402
# epi : 403
# epi : 404
# epi : 405
# epi : 406
# epi : 407
# epi : 408
# epi : 409
# epi : 410
# epi : 411
# epi : 412
# epi : 413
# epi : 414
# epi : 415
# epi : 416
# epi : 417
# epi : 418
# epi : 419
# epi : 420
# n_episode :420, score : 504.1, n_buffer : 100000, eps : 5.9%
# epi : 421
# epi : 422
# epi : 423
# epi : 424
# epi : 425
# epi : 426
# epi : 427
# epi : 428
# epi : 429
# epi : 430
# epi : 431
# epi : 432
# epi : 433
# epi : 434
# epi : 435
# epi : 436
# epi : 437
# epi : 438
# epi : 439
# epi : 440
# n_episode :440, score : 557.9, n_buffer : 100000, eps : 5.8%
# epi : 441
# epi : 442
# epi : 443
# epi : 444
# epi : 445
# epi : 446
# epi : 447
# epi : 448
# epi : 449
# epi : 450
# epi : 451
# epi : 452
# epi : 453
# epi : 454
# epi : 455
# epi : 456
# epi : 457
# epi : 458
# epi : 459
# epi : 460
# n_episode :460, score : 566.5, n_buffer : 100000, eps : 5.7%
# epi : 461
# epi : 462
# epi : 463
# epi : 464
# epi : 465
# epi : 466
# epi : 467
# epi : 468
# epi : 469
# epi : 470
# epi : 471
# epi : 472
# epi : 473
# epi : 474
# epi : 475
# epi : 476
# epi : 477
# epi : 478
# epi : 479
# epi : 480
# n_episode :480, score : 532.0, n_buffer : 100000, eps : 5.6%
# epi : 481
# epi : 482
# epi : 483
# epi : 484
# epi : 485
# epi : 486
# epi : 487
# epi : 488
# epi : 489
# epi : 490
# epi : 491
# epi : 492
# epi : 493
# epi : 494
# epi : 495
# epi : 496
# epi : 497
# epi : 498
# epi : 499
# epi : 500
# n_episode :500, score : 452.0, n_buffer : 100000, eps : 5.5%
# epi : 501
# epi : 502
# epi : 503
# epi : 504
# epi : 505
# epi : 506
# epi : 507
# epi : 508
# epi : 509
# epi : 510
# epi : 511
# epi : 512
# epi : 513
# epi : 514
# epi : 515
# epi : 516
# epi : 517
# epi : 518
# epi : 519
# epi : 520
# n_episode :520, score : 507.9, n_buffer : 100000, eps : 5.4%
# epi : 521
# epi : 522
# epi : 523
# epi : 524
# epi : 525
# epi : 526
# epi : 527
# epi : 528
# epi : 529
# epi : 530
# epi : 531
# epi : 532
# epi : 533
# epi : 534
# epi : 535
# epi : 536
# epi : 537
# epi : 538
# epi : 539
# epi : 540
# n_episode :540, score : 605.9, n_buffer : 100000, eps : 5.3%
# epi : 541
# epi : 542
# epi : 543
# epi : 544
# epi : 545
# epi : 546
# epi : 547
# epi : 548
# epi : 549
# epi : 550
# epi : 551
# epi : 552
# epi : 553
# epi : 554
# epi : 555
# epi : 556
# epi : 557
# epi : 558
# epi : 559
# epi : 560
# n_episode :560, score : 514.1, n_buffer : 100000, eps : 5.2%
# epi : 561
# epi : 562
# epi : 563
# epi : 564
# epi : 565
# epi : 566
# epi : 567
# epi : 568
# epi : 569
# epi : 570
# epi : 571
# epi : 572
# epi : 573
# epi : 574
# epi : 575
# epi : 576
# epi : 577
# epi : 578
# epi : 579
# epi : 580
# n_episode :580, score : 530.1, n_buffer : 100000, eps : 5.1%
# epi : 581
# epi : 582
# epi : 583
# epi : 584
# epi : 585
# epi : 586
# epi : 587
# epi : 588
# epi : 589
# epi : 590
# epi : 591
# epi : 592
# epi : 593
# epi : 594
# epi : 595
# epi : 596
# epi : 597
# epi : 598
# epi : 599
# epi : 600
# n_episode :600, score : 619.0, n_buffer : 100000, eps : 5.0%
# epi : 601
# epi : 602
# epi : 603
# epi : 604
# epi : 605
# epi : 606
# epi : 607
# epi : 608
# epi : 609
# epi : 610
# epi : 611
# epi : 612
# epi : 613
# epi : 614
# epi : 615
# epi : 616
# epi : 617
# epi : 618
# epi : 619
# epi : 620
# n_episode :620, score : 557.5, n_buffer : 100000, eps : 4.9%
# epi : 621
# epi : 622
# epi : 623
# epi : 624
# epi : 625
# epi : 626
# epi : 627
# epi : 628
# epi : 629
# epi : 630
# epi : 631
# epi : 632
# epi : 633
# epi : 634
# epi : 635
# epi : 636
# epi : 637
# epi : 638
# epi : 639
# epi : 640
# n_episode :640, score : 467.8, n_buffer : 100000, eps : 4.8%
# epi : 641
# epi : 642
# epi : 643
# epi : 644
# epi : 645
# epi : 646
# epi : 647
# epi : 648
# epi : 649
# epi : 650
# epi : 651
# epi : 652
# epi : 653
# epi : 654
# epi : 655
# epi : 656
# epi : 657
# epi : 658
# epi : 659
# epi : 660
# n_episode :660, score : 493.2, n_buffer : 100000, eps : 4.7%
# epi : 661
# epi : 662
# epi : 663
# epi : 664
# epi : 665
# epi : 666
# epi : 667
# epi : 668
# epi : 669
# epi : 670
# epi : 671
# epi : 672
# epi : 673
# epi : 674
# epi : 675
# epi : 676
# epi : 677
# epi : 678
# epi : 679
# epi : 680
# n_episode :680, score : 563.1, n_buffer : 100000, eps : 4.6%
# epi : 681
# epi : 682
# epi : 683
# epi : 684
# epi : 685
# epi : 686
# epi : 687
# epi : 688
# epi : 689
# epi : 690
# epi : 691
# epi : 692
# epi : 693
# epi : 694
# epi : 695
# epi : 696
# epi : 697
# epi : 698
# epi : 699
# epi : 700
# n_episode :700, score : 704.0, n_buffer : 100000, eps : 4.5%
# epi : 701
# epi : 702
# epi : 703
# epi : 704
# epi : 705
# epi : 706
# epi : 707
# epi : 708
# epi : 709
# epi : 710
# epi : 711
# epi : 712
# epi : 713
# epi : 714
# epi : 715
# epi : 716
# epi : 717
# epi : 718
# epi : 719
# epi : 720
# n_episode :720, score : 562.5, n_buffer : 100000, eps : 4.4%
# epi : 721
# epi : 722
# epi : 723
# epi : 724
# epi : 725
# epi : 726
# epi : 727
# epi : 728
# epi : 729
# epi : 730
# epi : 731
# epi : 732
# epi : 733
# epi : 734
# epi : 735
# epi : 736
# epi : 737
# epi : 738
# epi : 739
# epi : 740
# n_episode :740, score : 549.0, n_buffer : 100000, eps : 4.3%
# epi : 741
# epi : 742
# epi : 743
# epi : 744
# epi : 745
# epi : 746
# epi : 747
# epi : 748
# epi : 749
# epi : 750
# epi : 751
# epi : 752
# epi : 753
# epi : 754
# epi : 755
# epi : 756
# epi : 757
# epi : 758
# epi : 759
# epi : 760
# n_episode :760, score : 482.6, n_buffer : 100000, eps : 4.2%
# epi : 761
# epi : 762
# epi : 763
# epi : 764
# epi : 765
# epi : 766
# epi : 767
# epi : 768
# epi : 769
# epi : 770
# epi : 771
# epi : 772
# epi : 773
# epi : 774
# epi : 775
# epi : 776
# epi : 777
# epi : 778
# epi : 779
# epi : 780
# n_episode :780, score : 586.2, n_buffer : 100000, eps : 4.1%
# epi : 781
# epi : 782
# epi : 783
# epi : 784
# epi : 785
# epi : 786
# epi : 787
# epi : 788
# epi : 789
# epi : 790
# epi : 791
# epi : 792
# epi : 793
# epi : 794
# epi : 795
# epi : 796
# epi : 797
# epi : 798
# epi : 799
# epi : 800
# n_episode :800, score : 409.2, n_buffer : 100000, eps : 4.0%
# epi : 801
# epi : 802
# epi : 803
# epi : 804
# epi : 805
# epi : 806
# epi : 807
# epi : 808
# epi : 809
# epi : 810
# epi : 811
# epi : 812
# epi : 813
# epi : 814
# epi : 815
# epi : 816
# epi : 817
# epi : 818
# epi : 819
# epi : 820
# n_episode :820, score : 351.8, n_buffer : 100000, eps : 3.9%
# epi : 821
# epi : 822
# epi : 823
# epi : 824
# epi : 825
# epi : 826
# epi : 827
# epi : 828
# epi : 829
# epi : 830
# epi : 831
# epi : 832
# epi : 833
# epi : 834
# epi : 835
# epi : 836
# epi : 837
# epi : 838
# epi : 839
# epi : 840
# n_episode :840, score : 376.8, n_buffer : 100000, eps : 3.8%
# epi : 841
# epi : 842
# epi : 843
# epi : 844
# epi : 845
# epi : 846
# epi : 847
# epi : 848
# epi : 849
# epi : 850
# epi : 851
# epi : 852
# epi : 853
# epi : 854
# epi : 855
# epi : 856
# epi : 857
# epi : 858
# epi : 859
# epi : 860
# n_episode :860, score : 426.6, n_buffer : 100000, eps : 3.7%
# epi : 861
# epi : 862
# epi : 863
# epi : 864
# epi : 865
# epi : 866
# epi : 867
# epi : 868
# epi : 869
# epi : 870
# epi : 871
# epi : 872
# epi : 873
# epi : 874
# epi : 875
# epi : 876
# epi : 877
# epi : 878
# epi : 879
# epi : 880
# n_episode :880, score : 381.9, n_buffer : 100000, eps : 3.6%
# epi : 881
# epi : 882
# epi : 883
# epi : 884
# epi : 885
# epi : 886
# epi : 887
# epi : 888
# epi : 889
# epi : 890
# epi : 891
# epi : 892
# epi : 893
# epi : 894
# epi : 895
# epi : 896
# epi : 897
# epi : 898
# epi : 899
# epi : 900
# n_episode :900, score : 368.9, n_buffer : 100000, eps : 3.5%
# epi : 901
# epi : 902
# epi : 903
# epi : 904
# epi : 905
# epi : 906
# epi : 907
# epi : 908
# epi : 909
# epi : 910
# epi : 911
# epi : 912
# epi : 913
# epi : 914
# epi : 915
# epi : 916
# epi : 917
# epi : 918
# epi : 919
# epi : 920
# n_episode :920, score : 401.9, n_buffer : 100000, eps : 3.4%
# epi : 921
# epi : 922
# epi : 923
# epi : 924
# epi : 925
# epi : 926
# epi : 927
# epi : 928
# epi : 929
# epi : 930
# epi : 931
# epi : 932
# epi : 933
# epi : 934
# epi : 935
# epi : 936
# epi : 937
# epi : 938
# epi : 939
# epi : 940
# n_episode :940, score : 375.1, n_buffer : 100000, eps : 3.3%
# epi : 941
# epi : 942
# epi : 943
# epi : 944
# epi : 945
# epi : 946
# epi : 947
# epi : 948
# epi : 949
# epi : 950
# epi : 951
# epi : 952
# epi : 953
# epi : 954
# epi : 955
# epi : 956
# epi : 957
# epi : 958
# epi : 959
# epi : 960
# n_episode :960, score : 357.1, n_buffer : 100000, eps : 3.2%
# epi : 961
# epi : 962
# epi : 963
# epi : 964
# epi : 965
# epi : 966
# epi : 967
# epi : 968
# epi : 969
# epi : 970
# epi : 971
# epi : 972
# epi : 973
# epi : 974
# epi : 975
# epi : 976
# epi : 977
# epi : 978
# epi : 979
# epi : 980
# n_episode :980, score : 394.2, n_buffer : 100000, eps : 3.1%
# epi : 981
# epi : 982
# epi : 983
# epi : 984
# epi : 985
# epi : 986
# epi : 987
# epi : 988
# epi : 989
# epi : 990
# epi : 991
# epi : 992
# epi : 993
# epi : 994
# epi : 995
# epi : 996
# epi : 997
# epi : 998
# epi : 999
# epi : 1000
# n_episode :1000, score : 465.6, n_buffer : 100000, eps : 3.0%
# epi : 1001
# epi : 1002
# epi : 1003
# epi : 1004
# epi : 1005
# epi : 1006
# epi : 1007
# epi : 1008
# epi : 1009
# epi : 1010
# epi : 1011
# epi : 1012
# epi : 1013
# epi : 1014
# epi : 1015
# epi : 1016
# epi : 1017
# epi : 1018
# epi : 1019
# epi : 1020
# n_episode :1020, score : 348.4, n_buffer : 100000, eps : 2.9%
# epi : 1021
# epi : 1022
# epi : 1023
# epi : 1024
# epi : 1025
# epi : 1026
# epi : 1027
# epi : 1028
# epi : 1029
# epi : 1030
# epi : 1031
# epi : 1032
# epi : 1033
# epi : 1034
# epi : 1035
# epi : 1036
# epi : 1037
# epi : 1038
# epi : 1039
# epi : 1040
# n_episode :1040, score : 316.9, n_buffer : 100000, eps : 2.8%
# epi : 1041
# epi : 1042
# epi : 1043
# epi : 1044
# epi : 1045
# epi : 1046
# epi : 1047
# epi : 1048
# epi : 1049
# epi : 1050
# epi : 1051
# epi : 1052
# epi : 1053
# epi : 1054
# epi : 1055
# epi : 1056
# epi : 1057
# epi : 1058
# epi : 1059
# epi : 1060
# n_episode :1060, score : 394.8, n_buffer : 100000, eps : 2.7%
# epi : 1061
# epi : 1062
# epi : 1063
# epi : 1064
# epi : 1065
# epi : 1066
# epi : 1067
# epi : 1068
# epi : 1069
# epi : 1070
# epi : 1071
# epi : 1072
# epi : 1073
# epi : 1074
# epi : 1075
# epi : 1076
# epi : 1077
# epi : 1078
# epi : 1079
# epi : 1080
# n_episode :1080, score : 268.2, n_buffer : 100000, eps : 2.6%
# epi : 1081
# epi : 1082
# epi : 1083
# epi : 1084
# epi : 1085
# epi : 1086
# epi : 1087
# epi : 1088
# epi : 1089
# epi : 1090
# epi : 1091
# epi : 1092
# epi : 1093
# epi : 1094
# epi : 1095
# epi : 1096
# epi : 1097
# epi : 1098
# epi : 1099
# epi : 1100
# n_episode :1100, score : 287.9, n_buffer : 100000, eps : 2.5%
# epi : 1101
# epi : 1102
# epi : 1103
# epi : 1104
# epi : 1105
# epi : 1106
# epi : 1107
# epi : 1108
# epi : 1109
# epi : 1110
# epi : 1111
# epi : 1112
# epi : 1113
# epi : 1114
# epi : 1115
# epi : 1116
# epi : 1117
# epi : 1118
# epi : 1119
# epi : 1120
# n_episode :1120, score : 315.9, n_buffer : 100000, eps : 2.4%
# epi : 1121
# epi : 1122
# epi : 1123
# epi : 1124
# epi : 1125
# epi : 1126
# epi : 1127
# epi : 1128
# epi : 1129
# epi : 1130
# epi : 1131
# epi : 1132
# epi : 1133
# epi : 1134
# epi : 1135
# epi : 1136
# epi : 1137
# epi : 1138
# epi : 1139
# epi : 1140
# n_episode :1140, score : 304.6, n_buffer : 100000, eps : 2.3%
# epi : 1141
# epi : 1142
# epi : 1143
# epi : 1144
# epi : 1145
# epi : 1146
# epi : 1147
# epi : 1148
# epi : 1149
# epi : 1150
# epi : 1151
# epi : 1152
# epi : 1153
# epi : 1154
# epi : 1155
# epi : 1156
# epi : 1157
# epi : 1158
# epi : 1159
# epi : 1160
# n_episode :1160, score : 537.6, n_buffer : 100000, eps : 2.2%
# epi : 1161
# epi : 1162
# epi : 1163
# epi : 1164
# epi : 1165
# epi : 1166
# epi : 1167
# epi : 1168
# epi : 1169
# epi : 1170
# epi : 1171
# epi : 1172
# epi : 1173
# epi : 1174
# epi : 1175
# epi : 1176
# epi : 1177
# epi : 1178
# epi : 1179
# epi : 1180
# n_episode :1180, score : 377.9, n_buffer : 100000, eps : 2.1%
# epi : 1181
# epi : 1182
# epi : 1183
# epi : 1184
# epi : 1185
# epi : 1186
# epi : 1187
# epi : 1188
# epi : 1189
# epi : 1190
# epi : 1191
# epi : 1192
# epi : 1193
# epi : 1194
# epi : 1195
# epi : 1196
# epi : 1197
# epi : 1198
# epi : 1199
# epi : 1200
# n_episode :1200, score : 593.8, n_buffer : 100000, eps : 2.0%
# epi : 1201
# epi : 1202
# epi : 1203
# epi : 1204
# epi : 1205
# epi : 1206
# epi : 1207
# epi : 1208
# epi : 1209
# epi : 1210
# epi : 1211
# epi : 1212
# epi : 1213
# epi : 1214
# epi : 1215
# epi : 1216
# epi : 1217
# epi : 1218
# epi : 1219
# epi : 1220
# n_episode :1220, score : 642.4, n_buffer : 100000, eps : 1.9%
# epi : 1221
# epi : 1222
# epi : 1223
# epi : 1224
# epi : 1225
# epi : 1226
# epi : 1227
# epi : 1228
# epi : 1229
# epi : 1230
# epi : 1231
# epi : 1232
# epi : 1233
# epi : 1234
# epi : 1235
# epi : 1236
# epi : 1237
# epi : 1238
# epi : 1239
# epi : 1240
# n_episode :1240, score : 540.2, n_buffer : 100000, eps : 1.8%
# epi : 1241
# epi : 1242
# epi : 1243
# epi : 1244
# epi : 1245
# epi : 1246
# epi : 1247
# epi : 1248
# epi : 1249
# epi : 1250
# epi : 1251
# epi : 1252
# epi : 1253
# epi : 1254
# epi : 1255
# epi : 1256
# epi : 1257
# epi : 1258
# epi : 1259
# epi : 1260
# n_episode :1260, score : 438.6, n_buffer : 100000, eps : 1.7%
# epi : 1261
# epi : 1262
# epi : 1263
# epi : 1264
# epi : 1265
# epi : 1266
# epi : 1267
# epi : 1268
# epi : 1269
# epi : 1270
# epi : 1271
# epi : 1272
# epi : 1273
# epi : 1274
# epi : 1275
# epi : 1276
# epi : 1277
# epi : 1278
# epi : 1279
# epi : 1280
# n_episode :1280, score : 385.6, n_buffer : 100000, eps : 1.6%
# epi : 1281
# epi : 1282
# epi : 1283
# epi : 1284
# epi : 1285
# epi : 1286
# epi : 1287
# epi : 1288
# epi : 1289
# epi : 1290
# epi : 1291
# epi : 1292
# epi : 1293
# epi : 1294
# epi : 1295
# epi : 1296
# epi : 1297
# epi : 1298
# epi : 1299
# epi : 1300
# n_episode :1300, score : 389.4, n_buffer : 100000, eps : 1.5%
# epi : 1301
# epi : 1302
# epi : 1303
# epi : 1304
# epi : 1305
# epi : 1306
# epi : 1307
# epi : 1308
# epi : 1309
# epi : 1310
# epi : 1311
# epi : 1312
# epi : 1313
# epi : 1314
# epi : 1315
# epi : 1316
# epi : 1317
# epi : 1318
# epi : 1319
# epi : 1320
# n_episode :1320, score : 643.4, n_buffer : 100000, eps : 1.4%
# epi : 1321
# epi : 1322
# epi : 1323
# epi : 1324
# epi : 1325
# epi : 1326
# epi : 1327
# epi : 1328
# epi : 1329
# epi : 1330
# epi : 1331
# epi : 1332
# epi : 1333
# epi : 1334
# epi : 1335
# epi : 1336
# epi : 1337
# epi : 1338
# epi : 1339
# epi : 1340
# n_episode :1340, score : 488.5, n_buffer : 100000, eps : 1.3%
# epi : 1341
# epi : 1342
# epi : 1343
# epi : 1344
# epi : 1345
# epi : 1346
# epi : 1347
# epi : 1348
# epi : 1349
# epi : 1350
# epi : 1351
# epi : 1352
# epi : 1353
# epi : 1354
# epi : 1355
# epi : 1356
# epi : 1357
# epi : 1358
# epi : 1359
# epi : 1360
# n_episode :1360, score : 562.1, n_buffer : 100000, eps : 1.2%
# epi : 1361
# epi : 1362
# epi : 1363
# epi : 1364
# epi : 1365
# epi : 1366
# epi : 1367
# epi : 1368
# epi : 1369
# epi : 1370
# epi : 1371
# epi : 1372
# epi : 1373
# epi : 1374
# epi : 1375
# epi : 1376
# epi : 1377
# epi : 1378
# epi : 1379
# epi : 1380
# n_episode :1380, score : 379.4, n_buffer : 100000, eps : 1.1%
# epi : 1381
# epi : 1382
# epi : 1383
# epi : 1384
# epi : 1385
# epi : 1386
# epi : 1387
# epi : 1388
# epi : 1389
# epi : 1390
# epi : 1391
# epi : 1392
# epi : 1393
# epi : 1394
# epi : 1395
# epi : 1396
# epi : 1397
# epi : 1398
# epi : 1399
# epi : 1400
# n_episode :1400, score : 480.1, n_buffer : 100000, eps : 1.0%
# epi : 1401
# epi : 1402
# epi : 1403
# epi : 1404
# epi : 1405
# epi : 1406
# epi : 1407
# epi : 1408
# epi : 1409
# epi : 1410
# epi : 1411
# epi : 1412
# epi : 1413
# epi : 1414
# epi : 1415
# epi : 1416
# epi : 1417
# epi : 1418
# epi : 1419
# epi : 1420
# n_episode :1420, score : 498.5, n_buffer : 100000, eps : 1.0%
# epi : 1421
# epi : 1422
# epi : 1423
# epi : 1424
# epi : 1425
# epi : 1426
# epi : 1427
# epi : 1428
# epi : 1429
# epi : 1430
# epi : 1431
# epi : 1432
# epi : 1433
# epi : 1434
# epi : 1435
# epi : 1436
# epi : 1437
# epi : 1438
# epi : 1439
# epi : 1440
# n_episode :1440, score : 388.1, n_buffer : 100000, eps : 1.0%
# epi : 1441
# epi : 1442
# epi : 1443
# epi : 1444
# epi : 1445
# epi : 1446
# epi : 1447
# epi : 1448
# epi : 1449
# epi : 1450
# epi : 1451
# epi : 1452
# epi : 1453
# epi : 1454
# epi : 1455
# epi : 1456
# epi : 1457
# epi : 1458
# epi : 1459
# epi : 1460
# n_episode :1460, score : 571.0, n_buffer : 100000, eps : 1.0%
# epi : 1461
# epi : 1462
# epi : 1463
# epi : 1464
# epi : 1465
# epi : 1466
# epi : 1467
# epi : 1468
# epi : 1469
# epi : 1470
# epi : 1471
# epi : 1472
# epi : 1473
# epi : 1474
# epi : 1475
# epi : 1476
# epi : 1477
# epi : 1478
# epi : 1479
# epi : 1480
# n_episode :1480, score : 557.3, n_buffer : 100000, eps : 1.0%
# epi : 1481
# epi : 1482
# epi : 1483
# epi : 1484
# epi : 1485
# epi : 1486
# epi : 1487
# epi : 1488
# epi : 1489
# epi : 1490
# epi : 1491
# epi : 1492
# epi : 1493
# epi : 1494
# epi : 1495
# epi : 1496
# epi : 1497
# epi : 1498
# epi : 1499
# epi : 1500
# n_episode :1500, score : 619.5, n_buffer : 100000, eps : 1.0%
# epi : 1501
# epi : 1502
# epi : 1503
# epi : 1504
# epi : 1505
# epi : 1506
# epi : 1507
# epi : 1508
# epi : 1509
# epi : 1510
# epi : 1511
# epi : 1512
# epi : 1513
# epi : 1514
# epi : 1515
# epi : 1516
# epi : 1517
# epi : 1518
# epi : 1519
# epi : 1520
# n_episode :1520, score : 604.8, n_buffer : 100000, eps : 1.0%
# epi : 1521
# epi : 1522
# epi : 1523
# epi : 1524
# epi : 1525
# epi : 1526
# epi : 1527
# epi : 1528
# epi : 1529
# epi : 1530
# epi : 1531
# epi : 1532
# epi : 1533
# epi : 1534
# epi : 1535
# epi : 1536
# epi : 1537
# epi : 1538
# epi : 1539
# epi : 1540
# n_episode :1540, score : 399.6, n_buffer : 100000, eps : 1.0%
# epi : 1541
# epi : 1542
# epi : 1543
# epi : 1544
# epi : 1545
# epi : 1546
# epi : 1547
# epi : 1548
# epi : 1549
# epi : 1550
# epi : 1551
# epi : 1552
# epi : 1553
# epi : 1554
# epi : 1555
# epi : 1556
# epi : 1557
# epi : 1558
# epi : 1559
# epi : 1560
# n_episode :1560, score : 581.8, n_buffer : 100000, eps : 1.0%
# epi : 1561
# epi : 1562
# epi : 1563
# epi : 1564
# epi : 1565
# epi : 1566
# epi : 1567
# epi : 1568
# epi : 1569
# epi : 1570
# epi : 1571
# epi : 1572
# epi : 1573
# epi : 1574
# epi : 1575
# epi : 1576
# epi : 1577
# epi : 1578
# epi : 1579
# epi : 1580
# n_episode :1580, score : 795.5, n_buffer : 100000, eps : 1.0%
# epi : 1581
# epi : 1582
# epi : 1583
# epi : 1584
# epi : 1585
# epi : 1586
# epi : 1587
# epi : 1588
# epi : 1589
# epi : 1590
# epi : 1591
# epi : 1592
# epi : 1593
# epi : 1594
# epi : 1595
# epi : 1596
# epi : 1597
# epi : 1598
# epi : 1599
# epi : 1600
# n_episode :1600, score : 691.5, n_buffer : 100000, eps : 1.0%
# epi : 1601
# epi : 1602
# epi : 1603
# epi : 1604
# epi : 1605
# epi : 1606
# epi : 1607
# epi : 1608
# epi : 1609
# epi : 1610
# epi : 1611
# epi : 1612
# epi : 1613
# epi : 1614
# epi : 1615
# epi : 1616
# epi : 1617
# epi : 1618
# epi : 1619
# epi : 1620
# n_episode :1620, score : 651.6, n_buffer : 100000, eps : 1.0%
# epi : 1621
# epi : 1622
# epi : 1623
# epi : 1624
# epi : 1625
# epi : 1626
# epi : 1627
# epi : 1628
# epi : 1629
# epi : 1630
# epi : 1631
# epi : 1632
# epi : 1633
# epi : 1634
# epi : 1635
# epi : 1636
# epi : 1637
# epi : 1638
# epi : 1639
# epi : 1640
# n_episode :1640, score : 772.9, n_buffer : 100000, eps : 1.0%
# epi : 1641
# epi : 1642
# epi : 1643
# epi : 1644
# epi : 1645
# epi : 1646
# epi : 1647
# epi : 1648
# epi : 1649
# epi : 1650
# epi : 1651
# epi : 1652
# epi : 1653
# epi : 1654
# epi : 1655
# epi : 1656
# epi : 1657
# epi : 1658
# epi : 1659
# epi : 1660
# n_episode :1660, score : 868.0, n_buffer : 100000, eps : 1.0%
# epi : 1661
# epi : 1662
# epi : 1663
# epi : 1664
# epi : 1665
# epi : 1666
# epi : 1667
# epi : 1668
# epi : 1669
# epi : 1670
# epi : 1671
# epi : 1672
# epi : 1673
# epi : 1674
# epi : 1675
# epi : 1676
# epi : 1677
# epi : 1678
# epi : 1679
# epi : 1680
# n_episode :1680, score : 686.9, n_buffer : 100000, eps : 1.0%
# epi : 1681
# epi : 1682
# epi : 1683
# epi : 1684
# epi : 1685
# epi : 1686
# epi : 1687
# epi : 1688
# epi : 1689
# epi : 1690
# epi : 1691
# epi : 1692
# epi : 1693
# epi : 1694
# epi : 1695
# epi : 1696
# epi : 1697
# epi : 1698
# epi : 1699
# epi : 1700
# n_episode :1700, score : 774.1, n_buffer : 100000, eps : 1.0%
# epi : 1701
# epi : 1702
# epi : 1703
# epi : 1704
# epi : 1705
# epi : 1706
# epi : 1707
# epi : 1708
# epi : 1709
# epi : 1710
# epi : 1711
# epi : 1712
# epi : 1713
# epi : 1714
# epi : 1715
# epi : 1716
# epi : 1717
# epi : 1718
# epi : 1719
# epi : 1720
# n_episode :1720, score : 301.0, n_buffer : 100000, eps : 1.0%
# epi : 1721
# epi : 1722
# epi : 1723
# epi : 1724
# epi : 1725
# epi : 1726
# epi : 1727
# epi : 1728
# epi : 1729
# epi : 1730
# epi : 1731
# epi : 1732
# epi : 1733
# epi : 1734
# epi : 1735
# epi : 1736
# epi : 1737
# epi : 1738
# epi : 1739
# epi : 1740
# n_episode :1740, score : 559.8, n_buffer : 100000, eps : 1.0%
# epi : 1741
# epi : 1742
# epi : 1743
# epi : 1744
# epi : 1745
# epi : 1746
# epi : 1747
# epi : 1748
# epi : 1749
# epi : 1750
# epi : 1751
# epi : 1752
# epi : 1753
# epi : 1754
# epi : 1755
# epi : 1756
# epi : 1757
# epi : 1758
# epi : 1759
# epi : 1760
# n_episode :1760, score : 361.2, n_buffer : 100000, eps : 1.0%
# epi : 1761
# epi : 1762
# epi : 1763
# epi : 1764
# epi : 1765
# epi : 1766
# epi : 1767
# epi : 1768
# epi : 1769
# epi : 1770
# epi : 1771
# epi : 1772
# epi : 1773
# epi : 1774
# epi : 1775
# epi : 1776
# epi : 1777
# epi : 1778
# epi : 1779
# epi : 1780
# n_episode :1780, score : 521.2, n_buffer : 100000, eps : 1.0%
# epi : 1781
# epi : 1782
# epi : 1783
# epi : 1784
# epi : 1785
# epi : 1786
# epi : 1787
# epi : 1788
# epi : 1789
# epi : 1790
# epi : 1791
# epi : 1792
# epi : 1793
# epi : 1794
# epi : 1795
# epi : 1796
# epi : 1797
# epi : 1798
# epi : 1799
# epi : 1800
# n_episode :1800, score : 675.5, n_buffer : 100000, eps : 1.0%
# epi : 1801
# epi : 1802
# epi : 1803
# epi : 1804
# epi : 1805
# epi : 1806
# epi : 1807
# epi : 1808
# epi : 1809
# epi : 1810
# epi : 1811
# epi : 1812
# epi : 1813
# epi : 1814
# epi : 1815
# epi : 1816
# epi : 1817
# epi : 1818
# epi : 1819
# epi : 1820
# n_episode :1820, score : 479.9, n_buffer : 100000, eps : 1.0%
# epi : 1821
# epi : 1822
# epi : 1823
# epi : 1824
# epi : 1825
# epi : 1826
# epi : 1827
# epi : 1828
# epi : 1829
# epi : 1830
# epi : 1831
# epi : 1832
# epi : 1833
# epi : 1834
# epi : 1835
# epi : 1836
# epi : 1837
# epi : 1838
# epi : 1839
# epi : 1840
# n_episode :1840, score : 640.8, n_buffer : 100000, eps : 1.0%
# epi : 1841
# epi : 1842
# epi : 1843
# epi : 1844
# epi : 1845
# epi : 1846
# epi : 1847
# epi : 1848
# epi : 1849
# epi : 1850
# epi : 1851
# epi : 1852
# epi : 1853
# epi : 1854
# epi : 1855
# epi : 1856
# epi : 1857
# epi : 1858
# epi : 1859
# epi : 1860
# n_episode :1860, score : 398.4, n_buffer : 100000, eps : 1.0%
# epi : 1861
# epi : 1862
# epi : 1863
# epi : 1864
# epi : 1865
# epi : 1866
# epi : 1867
# epi : 1868
# epi : 1869
# epi : 1870
# epi : 1871
# epi : 1872
# epi : 1873
# epi : 1874
# epi : 1875
# epi : 1876
# epi : 1877
# epi : 1878
# epi : 1879
# epi : 1880
# n_episode :1880, score : 669.2, n_buffer : 100000, eps : 1.0%
# epi : 1881
# epi : 1882
# epi : 1883
# epi : 1884
# epi : 1885
# epi : 1886
# epi : 1887
# epi : 1888
# epi : 1889
# epi : 1890
# epi : 1891
# epi : 1892
# epi : 1893
# epi : 1894
# epi : 1895
# epi : 1896
# epi : 1897
# epi : 1898
# epi : 1899
# epi : 1900
# n_episode :1900, score : 880.6, n_buffer : 100000, eps : 1.0%
# epi : 1901
# epi : 1902
# epi : 1903
# epi : 1904
# epi : 1905
# epi : 1906
# epi : 1907
# epi : 1908
# epi : 1909
# epi : 1910
# epi : 1911
# epi : 1912
# epi : 1913
# epi : 1914
# epi : 1915
# epi : 1916
# epi : 1917
# epi : 1918
# epi : 1919
# epi : 1920
# n_episode :1920, score : 871.8, n_buffer : 100000, eps : 1.0%
# epi : 1921
# epi : 1922
# epi : 1923
# epi : 1924
# epi : 1925
# epi : 1926
# epi : 1927
# epi : 1928
# epi : 1929
# epi : 1930
# epi : 1931
# epi : 1932
# epi : 1933
# epi : 1934
# epi : 1935
# epi : 1936
# epi : 1937
# epi : 1938
# epi : 1939
# epi : 1940
# n_episode :1940, score : 956.0, n_buffer : 100000, eps : 1.0%
# epi : 1941
# epi : 1942
# epi : 1943
# epi : 1944
# epi : 1945
# epi : 1946
# epi : 1947
# epi : 1948
# epi : 1949
# epi : 1950
# epi : 1951
# epi : 1952
# epi : 1953
# epi : 1954
# epi : 1955
# epi : 1956
# epi : 1957
# epi : 1958
# epi : 1959
# epi : 1960
# n_episode :1960, score : 555.7, n_buffer : 100000, eps : 1.0%
# epi : 1961
# epi : 1962
# epi : 1963
# epi : 1964
# epi : 1965
# epi : 1966
# epi : 1967
# epi : 1968
# epi : 1969
# epi : 1970
# epi : 1971
# epi : 1972
# epi : 1973
# epi : 1974
# epi : 1975
# epi : 1976
# epi : 1977
# epi : 1978
# epi : 1979
# epi : 1980
# n_episode :1980, score : 417.1, n_buffer : 100000, eps : 1.0%
# epi : 1981
# epi : 1982
# epi : 1983
# epi : 1984
# epi : 1985
# epi : 1986
# epi : 1987
# epi : 1988
# epi : 1989
# epi : 1990
# epi : 1991
# epi : 1992
# epi : 1993
# epi : 1994
# epi : 1995
# epi : 1996
# epi : 1997
# epi : 1998
# epi : 1999
# epi : 2000
# n_episode :2000, score : 420.9, n_buffer : 100000, eps : 1.0%
# epi : 2001
# epi : 2002
# epi : 2003
# epi : 2004
# epi : 2005
# epi : 2006
# epi : 2007
# epi : 2008
# epi : 2009
# epi : 2010
# epi : 2011
# epi : 2012
# epi : 2013
# epi : 2014
# epi : 2015
# epi : 2016
# epi : 2017
# epi : 2018
# epi : 2019
# epi : 2020
# n_episode :2020, score : 444.9, n_buffer : 100000, eps : 1.0%
# epi : 2021
# epi : 2022
# epi : 2023
# epi : 2024
# epi : 2025
# epi : 2026
# epi : 2027
# epi : 2028
# epi : 2029
# epi : 2030
# epi : 2031
# epi : 2032
# epi : 2033
# epi : 2034
# epi : 2035
# epi : 2036
# epi : 2037
# epi : 2038
# epi : 2039
# epi : 2040
# n_episode :2040, score : 418.9, n_buffer : 100000, eps : 1.0%
# epi : 2041
# epi : 2042
# epi : 2043
# epi : 2044
# epi : 2045
# epi : 2046
# epi : 2047
# epi : 2048
# epi : 2049
# epi : 2050
# epi : 2051
# epi : 2052
# epi : 2053
# epi : 2054
# epi : 2055
# epi : 2056
# epi : 2057
# epi : 2058
# epi : 2059
# epi : 2060
# n_episode :2060, score : 375.2, n_buffer : 100000, eps : 1.0%
# epi : 2061
# epi : 2062
# epi : 2063
# epi : 2064
# epi : 2065
# epi : 2066
# epi : 2067
# epi : 2068
# epi : 2069
# epi : 2070
# epi : 2071
# epi : 2072
# epi : 2073
# epi : 2074
# epi : 2075
# epi : 2076
# epi : 2077
# epi : 2078
# epi : 2079
# epi : 2080
# n_episode :2080, score : 389.1, n_buffer : 100000, eps : 1.0%
# epi : 2081
# epi : 2082
# epi : 2083
# epi : 2084
# epi : 2085
# epi : 2086
# epi : 2087
# epi : 2088
# epi : 2089
# epi : 2090
# epi : 2091
# epi : 2092
# epi : 2093
# epi : 2094
